# %%
#Import Pandas as pd
import pandas as pd

# %% [markdown]
# The image below gives a description of the column headings
# ![Screenshot%20%2813%29.png](attachment:Screenshot%20%2813%29.png)
# <img src="Screenshot(13).png" alt="data description">

# %%
#importing the dataset
fuel_data=pd.read_csv('fuel_data.csv')

# %%
fuel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29523 entries, 0 to 29522
# Data columns (total 11 columns):
# record_id                       29523 non-null object
# utility_id_ferc1                29523 non-null int64
# report_year                     29523 non-null int64
# plant_name_ferc1                29523 non-null object
# fuel_type_code_pudl             29523 non-null object
# fuel_unit                       29343 non-null object
# fuel_qty_burned                 29523 non-null float64
# fuel_mmbtu_per_unit             29523 non-null float64
# fuel_cost_per_unit_burned       29523 non-null float64
# fuel_cost_per_unit_delivered    29523 non-null float64
# fuel_cost_per_mmbtu             29523 non-null float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 2.5+ MB

# %%
fuel_data.axes
# Out:
# [RangeIndex(start=0, stop=29523, step=1),
#  Index(['record_id', 'utility_id_ferc1', 'report_year', 'plant_name_ferc1',
#         'fuel_type_code_pudl', 'fuel_unit', 'fuel_qty_burned',
#         'fuel_mmbtu_per_unit', 'fuel_cost_per_unit_burned',
#         'fuel_cost_per_unit_delivered', 'fuel_cost_per_mmbtu'],
#        dtype='object')]

# %%
fuel_data.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
#Question 1
A=[1,2,3,4,5,6]
B=[13,21,34]
A.extend(B)

# %%
#question 2
import numpy as np
np.identity(3)

#np.eye(3) would also give the same result
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
#Question 3
fuel_data.pivot_table(index="fuel_type_code_pudl",values=["fuel_cost_per_unit_burned"],aggfunc=["mean"])
# Out:
#                                          mean
#                     fuel_cost_per_unit_burned
# fuel_type_code_pudl
# coal                                67.421830
# gas                                 13.659397
# nuclear                           4955.157002
# oil                                168.877086
# other                               18.253856
# waste                               19.518122

# %%
# Question 4
fuel_data.fuel_mmbtu_per_unit.describe()
# Out:
# count    29523.000000
# mean         8.492111
# std         10.600220
# min          0.000001
# 25%          1.024000
# 50%          5.762694
# 75%         17.006000
# max        341.260000
# Name: fuel_mmbtu_per_unit, dtype: float64

# %%
# Question 5
import math
print(round(fuel_data.fuel_qty_burned.skew(),2))
print(round(fuel_data.fuel_qty_burned.kurt(),2))
# Out:
# 15.85
# 651.37

# %%
# question 6
# to get the missing values in the dataset we use .isnull()
print(fuel_data.isnull().sum())
print(round((fuel_data['fuel_unit'].isnull().sum())/(len(fuel_data.fuel_unit))*100,3))
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64
# 0.61

# %%
len(fuel_data.fuel_unit)
# Out:
# 29523

# %% [markdown]
# # question 7
# categorical and mode imputation

# %% [markdown]
# Question 8

# %%
fuel_data.corr()
# Out:
#                               utility_id_ferc1  report_year  fuel_qty_burned  \
# utility_id_ferc1                      1.000000     0.093323        -0.057447
# report_year                           0.093323     1.000000         0.012952
# fuel_qty_burned                      -0.057447     0.012952         1.000000
# fuel_mmbtu_per_unit                  -0.066946    -0.110853        -0.080946
# fuel_cost_per_unit_burned            -0.037863     0.013599        -0.018535
# fuel_cost_per_unit_delivered         -0.016414    -0.014043        -0.003551
# fuel_cost_per_mmbtu                   0.006122     0.010261        -0.001896
#
#                               fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# utility_id_ferc1                        -0.066946                  -0.037863
# report_year                             -0.110853                   0.013599
# fuel_qty_burned                         -0.080946                  -0.018535
# ...

# %% [markdown]
# QUESTION 9

# %%
fuel_dt=fuel_data.groupby(['report_year','fuel_type_code_pudl'])['fuel_cost_per_unit_burned'].mean()

# %%
year_1994,year_1998=fuel_dt.loc[[1994,1998],'coal']
percent_change=((year_1998-year_1994)/(year_1994))*100
percent_change
# Out:
# -12.458551963280119

# %% [markdown]
# question 10

# %%
avg_fuel=fuel_data.pivot_table(index=['report_year'],values=['fuel_cost_per_unit_delivered'],aggfunc=['mean'])
avg_fuel=pd.DataFrame(avg_fuel)
avg_fuel.idxmax()
# Out:
# mean  fuel_cost_per_unit_delivered    1997
# dtype: int64
