# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('energydata_complete.csv')
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
#to check if there is any column with missing data
df.isnull().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
#droping data nd light columns
df.drop(['lights','date'],axis=1, inplace= True)

# %%
#scaling the variables in the dataset to give them same range.
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
normalized_df=pd.DataFrame(scaler.fit_transform(df),columns=df.columns)
features_df=normalized_df.drop(columns=['Appliances'])
target=normalized_df['Appliances']

# %%
features_df.describe()
# Out:
#                  T1          RH_1            T2          RH_2            T3  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean       0.517061      0.364271      0.308303      0.561170      0.421038
# std        0.169595      0.109512      0.159412      0.114438      0.166676
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.419219      0.283735      0.195542      0.490299      0.298272
# 50%        0.507920      0.347675      0.283499      0.563408      0.407112
# 75%        0.613516      0.441519      0.392537      0.641016      0.505982
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                RH_3            T4          RH_4            T5          RH_5  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean       0.489601      0.518499      0.485143      0.407272      0.317777
# ...

# %%
features_df.corr()
# Out:
#                    T1      RH_1        T2      RH_2        T3      RH_3  \
# T1           1.000000  0.164006  0.836834 -0.002509  0.892402 -0.028550
# RH_1         0.164006  1.000000  0.269839  0.797535  0.253230  0.844677
# T2           0.836834  0.269839  1.000000 -0.165610  0.735245  0.121497
# RH_2        -0.002509  0.797535 -0.165610  1.000000  0.137319  0.678326
# T3           0.892402  0.253230  0.735245  0.137319  1.000000 -0.011234
# RH_3        -0.028550  0.844677  0.121497  0.678326 -0.011234  1.000000
# T4           0.877001  0.106180  0.762066 -0.047304  0.852778 -0.140457
# RH_4         0.097861  0.880359  0.231563  0.721435  0.122737  0.898978
# T5           0.885247  0.205797  0.720550  0.110409  0.888169 -0.050062
# RH_5        -0.014782  0.303258  0.029595  0.250271 -0.066355  0.375422
# T6           0.654769  0.316141  0.801186 -0.009670  0.686882  0.076833
# RH_6        -0.615045  0.245126 -0.580372  0.389933 -0.647672  0.514912
# ...

# %% [markdown]
# Visualizations

# %%
normalized_df.corr()
# Out:
#              Appliances        T1      RH_1        T2      RH_2        T3  \
# Appliances     1.000000  0.055447  0.086031  0.120073 -0.060465  0.085060
# T1             0.055447  1.000000  0.164006  0.836834 -0.002509  0.892402
# RH_1           0.086031  0.164006  1.000000  0.269839  0.797535  0.253230
# T2             0.120073  0.836834  0.269839  1.000000 -0.165610  0.735245
# RH_2          -0.060465 -0.002509  0.797535 -0.165610  1.000000  0.137319
# T3             0.085060  0.892402  0.253230  0.735245  0.137319  1.000000
# RH_3           0.036292 -0.028550  0.844677  0.121497  0.678326 -0.011234
# T4             0.040281  0.877001  0.106180  0.762066 -0.047304  0.852778
# RH_4           0.016965  0.097861  0.880359  0.231563  0.721435  0.122737
# T5             0.019760  0.885247  0.205797  0.720550  0.110409  0.888169
# RH_5           0.006955 -0.014782  0.303258  0.029595  0.250271 -0.066355
# T6             0.117638  0.654769  0.316141  0.801186 -0.009670  0.686882
# ...

# %%
#regression plot
for i, col in enumerate(normalized_df):
    plt.figure(i)
    sns.regplot(x=col,y='Appliances',data=normalized_df)
# Out:
# C:\Users\Homet\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# from the above plot it confirms that the target column (appliances) does not have a strong correlation with other columns

# %%
#taking the temperature in one part of the room to generalize for other part of hthe room we can plot a residplot 
temp=normalized_df[['T1','T2','T3','T4','T5','T6','T7','T8','Appliances']]
for i,col in enumerate(temp):
    plt.figure(i)
    sns.residplot(x=col,y='Appliances',data=temp)

# %%
sns.heatmap(normalized_df.corr())

# %% [markdown]
# Building Models

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,r2_score

# %%
x_train,x_test,y_train,y_test=train_test_split(features_df,target,test_size=0.3,random_state=42)

# %%
lm=LinearRegression() 
lm.fit(x_train,y_train)
lm.score(x_test,y_test)
predic_lm=lm.predict(x_test)
print('r2 score on  training set is',lm.score(x_train,y_train))
print('r2 score on  test set is',lm.score(x_test,y_test))
print('mean absolute_error on predicted_values is : ',mean_absolute_error(y_test,predic_lm), 'and' 'r2 score is ',r2_score(y_test,predic_lm))
# Out:
# r2 score on  training set is 0.14471942308518737
# r2 score on  test set is 0.14890246319303535
# mean absolute_error on predicted_values is :  0.05013362397742954 andr2 score is  0.14890246319303535

# %%
#Ridge
# Using a ridge model 
from sklearn.linear_model import Ridge
ridge=Ridge(alpha=0.001)
ridge.fit(x_train,y_train)
ridge.score(x_test,y_test)
predic_ridge=ridge.predict(x_test)
print('r2 score on  training set is',ridge.score(x_train,y_train))
print('r2 score on  test set is',ridge.score(x_test,y_test))
print('mean absolute_error on predicted_values is : ',mean_absolute_error(y_test,predic_ridge), 'and' 'r2 score is ',r2_score(y_test,predic_ridge))
# Out:
# r2 score on  training set is 0.1447194213080064
# r2 score on  test set is 0.14890208646405834
# mean absolute_error on predicted_values is :  0.05013345224277053 andr2 score is  0.14890208646405834

# %%
#lasso
#using a lasso model
from sklearn.linear_model import Lasso
lasso=Lasso(alpha=0.0001,max_iter=1000 )
lasso.fit(x_train,y_train)
lasso.score(x_test,y_test)
predic_lasso=lasso.predict(x_test)
print('r2 score on  training set is',lasso.score(x_train,y_train))
print('r2 score on  test set is',lasso.score(x_test,y_test))
print('mean absolute_error on predicted_values is : ',mean_absolute_error(y_test,predic_lasso), 'and' 'r2 score is ',r2_score(y_test,predic_lasso))
print('number of features used= ',np.sum(lasso.coef_!=0))
# Out:
# r2 score on  training set is 0.13192682814450418
# r2 score on  test set is 0.13432492607212543
# mean absolute_error on predicted_values is :  0.05034694346626962 andr2 score is  0.13432492607212543
# number of features used=  16

# %%
def get_weights_df(model, feat, col_name):
  #this function returns the weight of every feature
    weights = pd.Series(model.coef_, feat.columns).sort_values()
    weights_df = pd.DataFrame(weights).reset_index()
    weights_df.columns = ['Features', col_name]
    weights_df[col_name].round(3)
    return weights_df

linear_model_weights = get_weights_df(lm, x_train, 'linear_model_weight')
ridge_weights_df = get_weights_df(ridge, x_train, 'ridge_weight')
lasso_weights_df = get_weights_df(lasso, x_train, 'Lasso_weight')

final_weights = pd.merge(linear_model_weights, ridge_weights_df, on='Features')
final_weights = pd.merge(final_weights, lasso_weights_df, on='Features')

# %%
final_weights
# Out:
#        Features  linear_model_weight  ridge_weight  Lasso_weight
# 0          RH_2            -0.456698     -0.456570     -0.164344
# 1         T_out            -0.321860     -0.321674     -0.000000
# 2            T2            -0.236178     -0.236080     -0.000000
# 3            T9            -0.189941     -0.189939     -0.164785
# 4          RH_8            -0.157595     -0.157594     -0.142142
# 5        RH_out            -0.077671     -0.077597     -0.000000
# 6          RH_7            -0.044614     -0.044617     -0.048415
# 7          RH_9            -0.039800     -0.039805     -0.028676
# 8            T5            -0.015657     -0.015669     -0.025671
# 9            T1            -0.003281     -0.003325     -0.051318
# 10          rv1             0.000770      0.000770      0.000000
# 11          rv2             0.000770      0.000770      0.000000
# 12  Press_mm_hg             0.006839      0.006839     -0.000000
# ...
